# %% [markdown]
# #### *Mounting Drive*

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # **Data Cleaning**
#
# ---

# %%
import pandas as pd
import numpy as np

# %%
data  = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/train_tmdb.csv")

# %%
data.head(3)
# Out:
#        id     budget                              genres  \
# 0  653346  160000000  Science Fiction, Adventure, Action
# 1  929590   50000000                  War, Action, Drama
# 2  823464  150000000  Science Fiction, Action, Adventure
#
#                                             homepage     imdb_id  \
# 0  https://www.20thcenturystudios.com/movies/king...  tt11389872
# 1               https://a24films.com/films/civil-war  tt17279496
# 2                 https://www.godzillaxkongmovie.com  tt14539740
#
#   original_language                     original_title  \
# 0                en  Kingdom of the Planet of the Apes
# 1                en                          Civil War
# 2                en    Godzilla x Kong: The New Empire
#
#                                             overview  popularity  \
# 0  Several generations in the future following Ca...    6245.898
# 1  In the near future, a group of war journalists...    2730.901
# 2  Following their explosive showdown, Godzilla a...    2726.153
#
#                         poster_path  ... release_date runtime  \
# 0  /gKkl37BQuKTanygYQG1pyYgLVgf.jpg  ...   2024-05-08     145
# 1  /sh7Rg8Er3tFcN9BpKIPOMvALgZd.jpg  ...   2024-04-10     109
# 2  /z1p34vh7dEOnLDmyCrlUVLuoDzd.jpg  ...   2024-03-27     115
#
#   spoken_languages    status                       tagline  \
# 0          English  Released    No one can stop the reign.
# 1          English  Released     Welcome to the frontline.
# 2          English  Released  Rise together or fall alone.
#
#                                title  \
# 0  Kingdom of the Planet of the Apes
# 1                          Civil War
# 2    Godzilla x Kong: The New Empire
#
#                                             keywords  \
# 0  empire, kingdom, gorilla, dystopia, eagle, seq...
# 1  sniper, new york city, race against time, wash...
# 2  giant monster, sequel, dinosaur, monkey, kaiju...
#
#                                                 cast  \
# 0  Owen Teague, Freya Allan, Kevin Durand, Peter ...
# 1  Kirsten Dunst, Wagner Moura, Cailee Spaeny, St...
# 2  Rebecca Hall, Brian Tyree Henry, Dan Stevens, ...
#
#                                                 crew    revenue
# 0  Wes Ball, Joe Hartwick Jr., Peter Chernin, Ric...  359039904
# 1  Andrew Macdonald, Allon Reich, Gregory Goodman...  114097977
# 2  Adam Wingard, Thomas Tull, Jon Jashni, Mary Pa...  567156493
#
# [3 rows x 22 columns]

# %% [markdown]
# ## Rename
#
# **homepage -> Movie_url**
#
# **original_title -> movie_title**

# %%
data.rename(columns= {'homepage':'movie_url', 'original_title':'movie_title'}, inplace= True)

# %% [markdown]
# ## Find the duplicates in data

# %%
data.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4002     True
# 4003     True
# 4004     True
# 4005    False
# 4006     True
# Length: 4007, dtype: bool

# %%
# checking the data_duplicates

print(f' # duplicates exist in data : {sum(data.duplicated())}')
# Out:
#  # duplicates exist in data : 34

# %% [markdown]
# drop duplicates

# %%
data.drop_duplicates(inplace= True)

# %%
# verify
sum(data.duplicated())
# Out:
# 0

# %%
data.describe()
# Out:
#                  id        budget   popularity      runtime       revenue
# count  3.973000e+03  3.973000e+03  3973.000000  3973.000000  3.973000e+03
# mean   1.680986e+05  4.318573e+07    57.799893   110.023660  1.329655e+08
# std    2.459848e+05  5.116684e+07   147.626042    21.431616  2.182136e+08
# min    5.000000e+00  0.000000e+00    16.329000     0.000000  0.000000e+00
# 25%    8.909000e+03  9.000000e+06    25.940000    95.000000  1.160000e+07
# 50%    1.972400e+04  2.500000e+07    36.333000   107.000000  5.330000e+07
# 75%    3.013510e+05  6.000000e+07    54.786000   121.000000  1.598145e+08
# max    1.260040e+06  4.600000e+08  6245.898000   248.000000  2.923706e+09

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3973 entries, 0 to 4005
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    3973 non-null   int64
#  1   budget                3973 non-null   int64
#  2   genres                3971 non-null   object
#  3   movie_url             2026 non-null   object
#  4   imdb_id               3973 non-null   object
#  5   original_language     3973 non-null   object
#  6   movie_title           3972 non-null   object
#  7   overview              3973 non-null   object
#  8   popularity            3973 non-null   float64
#  9   poster_path           3973 non-null   object
#  10  production_companies  3965 non-null   object
#  11  production_countries  3972 non-null   object
#  12  release_date          3973 non-null   object
#  13  runtime               3973 non-null   int64
#  14  spoken_languages      3971 non-null   object
#  15  status                3973 non-null   object
#  16  tagline               3823 non-null   object
#  17  title                 3973 non-null   object
#  18  keywords              3941 non-null   object
#  19  cast                  3972 non-null   object
#  20  crew                  3973 non-null   object
#  21  revenue               3973 non-null   int64
# dtypes: float64(1), int64(4), object(17)
# memory usage: 713.9+ KB

# %% [markdown]
# ### Use the API calls to replacing the missing values in data

# %%
async def main(movie_id,column):
    async with s.aiohttp.ClientSession() as Session:
        # fetching the tmdb movie page

        # fetching the movie details
        movie_details = [s.fetch_movie_details(Session, i) for i in movie_id]

        details_response = await s.asyncio.gather(*movie_details)

        # fetching keywords
        task = [s.keywords(Session,i) for i in movie_id]

        key_response = await s.asyncio.gather(*task)
        # fetching the credits
        credit_task = [s.credits(Session,i) for i in movie_id]

        credit_response = await s.asyncio.gather(*credit_task)

        # list for storing the row
        details_list = []

        for response, key, credit, movie_id in zip(details_response,key_response, credit_response,movie_id):
            if response['budget'] > 0:
                top_cast = credit.get('cast', [])[:5]
                top_crew = credit.get('crew', [])[:5]

                try:
                    new_rows = {
                        'id': movie_id,
                        'imdb_id': response.get('imdb_id'),
                        'title': response.get('title'),
                        'original_language': response.get('original_language'),
                        'movie_title': response.get('original_title'),
                        'origin_country': ', '.join(response.get('origin_country')),
                        'genres': ', '.join([genre.get('name') for genre in response.get('genres')]),
                        'production_companies': ', '.join([company.get('name') for company in response.get('production_companies')]),
                        'production_countries': ', '.join([country.get('name') for country in response.get('production_countries')]),
                        'runtime_in_mins': response.get('runtime'),
                        'spoken_languages': ', '.join([lang.get('name') for lang in response.get('spoken_languages')]),
                        'status': response.get('status'),
                        'tagline': response.get('tagline'),
                        'movie_url': response.get('homepage'),
                        'popularity': response.get('popularity'),
                        'release_date': response.get('release_date'),
                        'overview': response.get('overview'),
                        'vote_count': response.get('vote_count'),
                        'vote_average': response.get('vote_average'),
                        'keywords': ", ".join([keyword.get('name') for keyword in key.get('keywords')]),
                        'cast': ", ".join([cast.get("name") for cast in top_cast]),
                        'crew': ", ".join([crew.get("name") for crew in top_crew]),
                        'revenue': response.get('revenue')
                    }
                    # appending the rows to details_list
                    details_list.append(new_rows)
                except Exception as e:
                    s.logging.error(f'error in proccesing movie_id {movie_id};  {s.traceback.format_exc()}"')
        # creating the DataFrame using the details_list

        return ''.join([movie[column] for movie in details_list])

# %% [markdown]
# Categorical and numerical columns

# %%
col = data.columns.to_list()
col
# Out:
# ['id',
#  'budget',
#  'genres',
#  'movie_url',
#  'imdb_id',
#  'original_language',
#  'movie_title',
#  'overview',
#  'popularity',
#  'poster_path',
#  'production_companies',
#  'production_countries',
#  'release_date',
#  'runtime',
#  'spoken_languages',
#  'status',
#  'tagline',
#  'title',
#  'keywords',
#  'cast',
#  'crew',
#  'revenue']

# %%
cols = data[data[col].isnull().any(axis=1)]
cols
# Out:
#            id     budget                                      genres  \
# 8     1011985   80000000  Animation, Action, Family, Comedy, Fantasy
# 10     882059   18000000                                         NaN
# 19     385687  340000000                                         NaN
# 29     934632   83000000              Science Fiction, Action, Drama
# 51     475557   55000000                      Crime, Thriller, Drama
# ...       ...        ...                                         ...
# 3993   693827    5000000                      Crime, Drama, Thriller
# 3994    13920   35000000                                       Drama
# 3995    10060   40000000                         Drama, Crime, Music
# 3996    71700    1600000       Drama, Action, Crime, Science Fiction
# 4005   882059   18000000    Action, Thriller, Crime, Science Fiction
#
#                                               movie_url     imdb_id  \
# 8     https://www.dreamworks.com/movies/kung-fu-panda-4  tt21692408
# 10                   https://www.boykillsworldmovie.com  tt13923084
# 19                               https://fastxmovie.com   tt5433140
# 29               https://www.netflix.com/title/81624666  tt23137904
# 51                           http://www.jokermovie.net/   tt7286456
# ...                                                 ...         ...
# 3993                                                NaN   tt5078852
# 3994                                                NaN   tt0316465
# 3995                                                NaN   tt0430308
# 3996                                                NaN   tt1580426
# 4005                 https://www.boykillsworldmovie.com  tt13923084
#
#      original_language                           movie_title  \
# 8                   en                       Kung Fu Panda 4
# 10                  en                       Boy Kills World
# 19                  en                                Fast X
# 29                  en  Rebel Moon - Part Two: The Scargiver
# 51                  en                                   NaN
# ...                ...                                   ...
# 3993                en                                Lansky
# 3994                en                                 Radio
# 3995                en                Get Rich or Die Tryin'
# 3996                en                             Repeaters
# 4005                en                       Boy Kills World
#
#                                                overview  popularity  \
# 8     Po is gearing up to become the spiritual leade...    1061.125
# 10    When his family is murdered, a deaf-mute named...     934.001
# 19    Over many missions and against impossible odds...     420.774
# 29    The rebels gear up for battle against the ruth...     413.025
# 51    During the 1980s, a failed stand-up comedian i...     228.080
# ...                                                 ...         ...
# 3993  When the aging Meyer Lansky is investigated on...      33.843
# 3994  High school football coach, Harold Jones befri...      23.826
# 3995  A tale of an inner city drug dealer who turns ...      23.576
# 3996  A gritty mind-bending thriller about three twe...      33.078
# 4005  When his family is murdered, a deaf-mute named...     934.001
#
#                            poster_path  ... release_date runtime  \
# 8     /kDp1vUBnMpe8ak4rjgl3cLELqjU.jpg  ...   2024-03-02      94
# 10    /25JskXmchcYwj3jHRmcPm738MpB.jpg  ...   2024-04-24     110
# 19    /fiVW06jE7z9YnO4trhaMEdclSiC.jpg  ...   2023-05-17     142
# 29    /cxevDYdeFkiixRShbObdwAHBZry.jpg  ...   2024-04-19     123
# 51    /udDclJoHjfjb8Ekgsd4FDteOkCU.jpg  ...   2019-10-01     122
# ...                                ...  ...          ...     ...
# 3993  /weNMzi7WXuzoml2Wvm1VMEE7Ipq.jpg  ...   2021-06-24     119
# 3994  /uQ6ci4iFHhB6TWB2f4wftR7AEly.jpg  ...   2003-10-24     109
# 3995  /aaEJu8vFKtrAoSRtw3xjCf1aM5d.jpg  ...   2005-11-09     117
# 3996  /9nQuL87o5AcUayeZM3cOXw1VbIv.jpg  ...   2011-04-22      89
# 4005  /25JskXmchcYwj3jHRmcPm738MpB.jpg  ...   2024-04-24     110
#
#        spoken_languages    status  \
# 8               English  Released
# 10              English  Released
# 19              English  Released
# 29              English  Released
# 51              English  Released
# ...                 ...       ...
# 3993  עִבְרִית, English  Released
# 3994   English, Pусский  Released
# 3995   English, Español  Released
# 3996            English  Released
# 4005            English  Released
#
#                                                 tagline  \
# 8                                                   NaN
# 10                                                  NaN
# 19                          The end of the road begins.
# 29                                                  NaN
# 51                                 Put on a happy face.
# ...                                                 ...
# 3993  The man who turned crime into a billion dollar...
# 3994                   His courage made them champions.
# 3995  If you think you know the story... You don't k...
# 3996                                                NaN
# 4005                                                NaN
#
#                                      title  \
# 8                          Kung Fu Panda 4
# 10                         Boy Kills World
# 19                                  Fast X
# 29    Rebel Moon - Part Two: The Scargiver
# 51                                   Joker
# ...                                    ...
# 3993                                Lansky
# 3994                                 Radio
# 3995                Get Rich or Die Tryin'
# 3996                             Repeaters
# 4005                       Boy Kills World
#
#                                                keywords  \
# 8     martial arts, kung fu, china, sequel, panda, a...
# 10    resistance, dystopia, deaf-mute, gore, halluci...
# 19    sequel, revenge, betrayal, racing, family, cli...
# 29    space war, space, female protagonist, space op...
# 51    dream, street gang, society, psychopath, clown...
# ...                                                 ...
# 3993  gangster, crime boss, mafia boss, organized cr...
# 3994                      friendship, sports, biography
# 3995  career, street gang, loss of loved one, rapper...
# 3996     time loop, recovering addict, group of friends
# 4005  resistance, dystopia, deaf-mute, gore, halluci...
#
#                                                    cast  \
# 8     Jack Black, Awkwafina, Viola Davis, Dustin Hof...
# 10    Bill Skarsgård, Jessica Rothe, Michelle Docker...
# 19    Vin Diesel, Michelle Rodriguez, Tyrese Gibson,...
# 29    Sofia Boutella, Michiel Huisman, Ed Skrein, Dj...
# 51    Joaquin Phoenix, Robert De Niro, Zazie Beetz, ...
# ...                                                 ...
# 3993  Harvey Keitel, Sam Worthington, John Magaro, M...
# 3994  Cuba Gooding Jr., Ed Harris, Alfre Woodard, S....
# 3995  50 Cent, Joy Bryant, Adewale Akinnuoye-Agbaje,...
# 3996  Dustin Milligan, Amanda Crew, Richard de Klerk...
# 4005  Bill Skarsgård, Jessica Rothe, Michelle Docker...
#
#                                                    crew     revenue
# 8     Natalia Cronembold, Stephanie Ma Stine, Rebecc...   539271347
# 10    Moritz Mohr, Sam Raimi, Roy Lee, Zainab Azizi,...     3128540
# 19    Gary Scott Thompson, Stephen F. Windon, Neal H...   704709660
# 29    Zack Snyder, Dody Dorn, Zack Snyder, Zack Snyd...           0
# 51    Todd Phillips, Bradley Cooper, Emma Tillinger ...  1078958629
# ...                                                 ...         ...
# 3993  Peter Flinckenberg, Laura Belle, Eytan Rockawa...      136579
# 3994  Mike Rich, Michael Tollin, Herb Gains, Clay A....    53293628
# 3995  Chris Lighty, Arthur Lappin, Jim Sheridan, Con...    46442528
# 3996  Carl Bessai, Andrew Herwitz, Irene Nelson, Arn...           0
# 4005  Moritz Mohr, Sam Raimi, Roy Lee, Zainab Azizi,...     3128540
#
# [2041 rows x 22 columns]

# %%
na_ids = cols['id'].to_list()

# %%
def update_missing_values(data, missing_ids, cols):
  for id in missing_ids:
    for col_ in cols:
      idx = data.index[data['id'] == id].to_list()[0]
      if pd.isnull(data.at[idx, col_]):
        data.at[idx, col_] = s.asyncio.run(main([id], col_))
  return data

# %%
new_data = update_missing_values(data, na_ids, cols)

# %% [markdown]
# ### saving the updated data file (where features.values are missing in data)

# %%
new_data.to_csv('/content/drive/MyDrive/Colab Notebooks/new_data.csv')

# %%
Data = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/new_data.csv')

# %%
Data.head()
# Out:
#    Unnamed: 0      id     budget                              genres  \
# 0           0  653346  160000000  Science Fiction, Adventure, Action
# 1           1  929590   50000000                  War, Action, Drama
# 2           2  823464  150000000  Science Fiction, Action, Adventure
# 3           3  719221    8000000                    Horror, Thriller
# 4           4  573435  100000000             Action, Crime, Thriller
#
#                                            movie_url     imdb_id  \
# 0  https://www.20thcenturystudios.com/movies/king...  tt11389872
# 1               https://a24films.com/films/civil-war  tt17279496
# 2                 https://www.godzillaxkongmovie.com  tt14539740
# 3                         https://www.tarotmovie.com  tt14088510
# 4                          https://www.badboys.movie   tt4919268
#
#   original_language                        movie_title  \
# 0                en  Kingdom of the Planet of the Apes
# 1                en                          Civil War
# 2                en    Godzilla x Kong: The New Empire
# 3                en                              Tarot
# 4                en              Bad Boys: Ride or Die
#
#                                             overview  popularity  ...  \
# 0  Several generations in the future following Ca...    6245.898  ...
# 1  In the near future, a group of war journalists...    2730.901  ...
# 2  Following their explosive showdown, Godzilla a...    2726.153  ...
# 3  When a group of friends recklessly violate the...    2349.378  ...
# 4  After their late former Captain is framed, Low...    2486.516  ...
#
#   release_date runtime spoken_languages    status  \
# 0   2024-05-08     145          English  Released
# 1   2024-04-10     109          English  Released
# 2   2024-03-27     115          English  Released
# 3   2024-05-01      92          English  Released
# 4   2024-06-05     115          English  Released
#
#                                    tagline                              title  \
# 0               No one can stop the reign.  Kingdom of the Planet of the Apes
# 1                Welcome to the frontline.                          Civil War
# 2             Rise together or fall alone.    Godzilla x Kong: The New Empire
# 3               Your fate is in the cards.                              Tarot
# 4  Miami's finest are now its most wanted.              Bad Boys: Ride or Die
#
#                                             keywords  \
# 0  empire, kingdom, gorilla, dystopia, eagle, seq...
# 1  sniper, new york city, race against time, wash...
# 2  giant monster, sequel, dinosaur, monkey, kaiju...
# 3  tarot cards, fate, slasher, group of friends, ...
# 4  miami, florida, on the run, police detective, ...
#
#                                                 cast  \
# 0  Owen Teague, Freya Allan, Kevin Durand, Peter ...
# 1  Kirsten Dunst, Wagner Moura, Cailee Spaeny, St...
# 2  Rebecca Hall, Brian Tyree Henry, Dan Stevens, ...
# 3  Harriet Slater, Adain Bradley, Avantika, Jacob...
# 4  Will Smith, Martin Lawrence, Vanessa Hudgens, ...
#
#                                                 crew    revenue
# 0  Wes Ball, Joe Hartwick Jr., Peter Chernin, Ric...  359039904
# 1  Andrew Macdonald, Allon Reich, Gregory Goodman...  114097977
# 2  Adam Wingard, Thomas Tull, Jon Jashni, Mary Pa...  567156493
# 3  Anna Halberg, Spenser Cohen, Spenser Cohen, An...   41989392
# 4  George Gallo, Jerry Bruckheimer, Adil El Arbi,...  104600000
#
# [5 rows x 23 columns]

# %%
Data.drop(columns='Unnamed: 0', axis=1, inplace = True)

# %%
sum(Data.duplicated())
# Out:
# 1

# %%
Data.drop_duplicates(inplace= True)

# %%
categorical_data = Data.select_dtypes(include= ['object'])

categorical_cols = [col for col in categorical_data.columns]

numerical_data = Data.select_dtypes(include= ['float64', 'int64'])

numerical_cols =[ num for num in numerical_data.columns]

# %%
categorical_cols
# Out:
# ['genres',
#  'movie_url',
#  'imdb_id',
#  'original_language',
#  'movie_title',
#  'overview',
#  'poster_path',
#  'production_companies',
#  'production_countries',
#  'release_date',
#  'spoken_languages',
#  'status',
#  'tagline',
#  'title',
#  'keywords',
#  'cast',
#  'crew']

# %% [markdown]
# ## replacing the revenue of 0 to Na and empty string to Na

# %%
Data.replace('', np.nan, inplace= True)
Data['revenue'].replace(0, np.nan,inplace= True)

# %%
# pd.set_option('display.max_rows', 500)

# %% [markdown]
# ## Mean Imputation & Mode Imputation

# %%
for cat_column, num_column in zip(categorical_cols, numerical_cols):
  Data[cat_column].fillna(Data[cat_column].mode()[0], inplace= True)
  Data[num_column].fillna(Data[num_column].mean(), inplace= True)

# %%
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3972 entries, 0 to 3971
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    3972 non-null   int64
#  1   budget                3972 non-null   int64
#  2   genres                3972 non-null   object
#  3   movie_url             3972 non-null   object
#  4   imdb_id               3972 non-null   object
#  5   original_language     3972 non-null   object
#  6   movie_title           3972 non-null   object
#  7   overview              3972 non-null   object
#  8   popularity            3972 non-null   float64
#  9   poster_path           3972 non-null   object
#  10  production_companies  3964 non-null   object
#  11  production_countries  3971 non-null   object
#  12  release_date          3972 non-null   object
#  13  runtime               3972 non-null   int64
#  14  spoken_languages      3970 non-null   object
#  15  status                3972 non-null   object
#  16  tagline               3823 non-null   object
#  17  title                 3972 non-null   object
#  18  keywords              3941 non-null   object
#  19  cast                  3971 non-null   object
#  20  crew                  3972 non-null   object
#  21  revenue               3972 non-null   float64
# dtypes: float64(2), int64(3), object(17)
# memory usage: 713.7+ KB

# %%
Data.isnull().sum()
# Out:
# id                        0
# budget                    0
# genres                    0
# movie_url                 0
# imdb_id                   0
# original_language         0
# movie_title               0
# overview                  0
# popularity                0
# poster_path               0
# production_companies      8
# production_countries      1
# release_date              0
# runtime                   0
# spoken_languages          2
# status                    0
# tagline                 149
# title                     0
# keywords                 31
# cast                      1
# crew                      0
# revenue                   0
# dtype: int64

# %%
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3972 entries, 0 to 3971
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    3972 non-null   int64
#  1   budget                3972 non-null   int64
#  2   genres                3972 non-null   object
#  3   movie_url             3972 non-null   object
#  4   imdb_id               3972 non-null   object
#  5   original_language     3972 non-null   object
#  6   movie_title           3972 non-null   object
#  7   overview              3972 non-null   object
#  8   popularity            3972 non-null   float64
#  9   poster_path           3972 non-null   object
#  10  production_companies  3964 non-null   object
#  11  production_countries  3971 non-null   object
#  12  release_date          3972 non-null   object
#  13  runtime               3972 non-null   int64
#  14  spoken_languages      3970 non-null   object
#  15  status                3972 non-null   object
#  16  tagline               3823 non-null   object
#  17  title                 3972 non-null   object
#  18  keywords              3941 non-null   object
#  19  cast                  3971 non-null   object
#  20  crew                  3972 non-null   object
#  21  revenue               3972 non-null   float64
# dtypes: float64(2), int64(3), object(17)
# memory usage: 713.7+ KB

# %%
Data['tagline'].replace(np.nan, 'No Tagline', inplace= True)
Data['keywords'].replace(np.nan, 'No Keywords', inplace= True)

# %%
Data.isnull().sum()
# Out:
# id                      0
# budget                  0
# genres                  0
# movie_url               0
# imdb_id                 0
# original_language       0
# movie_title             0
# overview                0
# popularity              0
# poster_path             0
# production_companies    8
# production_countries    1
# release_date            0
# runtime                 0
# spoken_languages        2
# status                  0
# tagline                 0
# title                   0
# keywords                0
# cast                    1
# crew                    0
# revenue                 0
# dtype: int64

# %%
# delete rows  where values are null following features.

Data = Data[~Data['production_companies'].isnull()]
Data = Data[~Data['production_countries'].isnull()]
Data = Data[~Data['spoken_languages'].isnull()]
Data = Data[~Data['cast'].isnull()]

# %%
Data.isnull().sum()
# Out:
# id                      0
# budget                  0
# genres                  0
# movie_url               0
# imdb_id                 0
# original_language       0
# movie_title             0
# overview                0
# popularity              0
# poster_path             0
# production_companies    0
# production_countries    0
# release_date            0
# runtime                 0
# spoken_languages        0
# status                  0
# tagline                 0
# title                   0
# keywords                0
# cast                    0
# crew                    0
# revenue                 0
# dtype: int64

# %%
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3961 entries, 0 to 3971
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    3961 non-null   int64
#  1   budget                3961 non-null   int64
#  2   genres                3961 non-null   object
#  3   movie_url             3961 non-null   object
#  4   imdb_id               3961 non-null   object
#  5   original_language     3961 non-null   object
#  6   movie_title           3961 non-null   object
#  7   overview              3961 non-null   object
#  8   popularity            3961 non-null   float64
#  9   poster_path           3961 non-null   object
#  10  production_companies  3961 non-null   object
#  11  production_countries  3961 non-null   object
#  12  release_date          3961 non-null   object
#  13  runtime               3961 non-null   int64
#  14  spoken_languages      3961 non-null   object
#  15  status                3961 non-null   object
#  16  tagline               3961 non-null   object
#  17  title                 3961 non-null   object
#  18  keywords              3961 non-null   object
#  19  cast                  3961 non-null   object
#  20  crew                  3961 non-null   object
#  21  revenue               3961 non-null   float64
# dtypes: float64(2), int64(3), object(17)
# memory usage: 711.7+ KB

# %% [markdown]
# ### Save the data to csv file <Cleaned.csv>

# %%
Data.to_csv(r'/content/drive/MyDrive/Colab Notebooks/Cleaned.csv')

# %% [markdown]
# # **Exploratory Data Analysis --EDA**
#
# ---

# %%
Data = pd.read_csv(r'/content/drive/MyDrive/Colab Notebooks/Cleaned.csv')

# %%
Data.drop('Unnamed: 0', axis =1, inplace= True)

# %%
! pip install plotly
# Out:
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (5.15.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly) (8.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from plotly) (24.1)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %% [markdown]
# ### **Distribution of Box Office Revenue**

# %%
Data['log_revenue'] = np.log1p((Data['revenue']/ 1e9))

fig = px.histogram(Data, x= 'log_revenue', nbins= 30,
                   title = "Distribution of Box Office Revenue",
                   labels = {'log_revenue':'revenue'})
fig.update_layout(bargap= 0.1)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="4d5964e1-b89a-4bfd-a8ea-3cd0f6c787a2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4d5964e1-b89a-4bfd-a8ea-3cd0f6c787a2")) {                    Plotly.newPlot(                        "4d5964e1-b89a-4bfd-a8ea-3cd0f6c787a2",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"revenue=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","nbinsx":30,"offsetgroup":"","orientation":"v","showlegend":false,"x":[0.30677849750466935,0.10804508826602878,0.44926282628786374,0.04113176285708945,0.09948327848495012,0.1349623039532406,0.15272325439728937,0.052297844108485286,0.4313091531554398,0.13458347374304458,0.0031236563019794434,0.5375713617877569,0.1762305441825591,0.6192913472319426,0.0220695783688465,0.35522756779504977,0.26129814713554456,0.021104683174966176,0.6688544879909007,0.533394808844907,0.18279472233348282,0.1349623039532406,0.24490504309572247,0.14904050222529266,0.09558179473183231,0.04092456365986108,0.3113771913692507,0.13226173294768967,0.3418673908535791,0.1349623039532406,0.5715443588006965,0.6184695120831619,0.24164302084942796,0.5782061103788118,0.07545175458783378,0.1349623039532406,0.38084270476973237,0.20632084697806208,0.09978361451301174,0.6180473814776992,0.014633298130413195,0.2594269385927152,0.48999147958314704,0.7567867568301252,0.6010158180580478,0.06945475413606944,0.24006620251641012,0.894306201726235,0.4818219148796192,0.1349623039532406,0.8543838736188256,0.7318671092069793,0.4848511885569144,0.3212558669209368,0.536870238672129,0.08644391493015269,0.5740246270875226,0.03813306803556037,0.2271334689958773,0.2031857119732638,0.7664108359857351,0.5316449140851369,0.5441787940080549,0.05949457178563976,0.18514106657128193,1.1159330933639373,0.1421248311620813,0.1882125035444041,0.1938620105201576,0.09373399099840421,0.8595087177751706,0.2158302848523184,0.007472014838700995,4.999987500041667e-06,0.601871869911955,0.19465466538802387,0.4100545604419717,0.2627488059065692,0.2774044380406467,0.006441160117299572,0.3992590657363867,0.03950913309471249,0.18298800133711515,0.24565181546383164,0.2021341791382229,0.0011383768031862466,0.36394842790523074,0.010495083438630695,0.026836653953559674,1.0722159885509661,0.6316305470505973,0.6200936582785044,0.1549809453471467,0.022952562996408157,0.05204645763888962,0.5252596955333318,0.28315573828952995,0.033763395199181506,0.4027948795522855,0.22509602319985375,0.16373319198260175,0.38570651984225235,0.06143707192474187,0.028178856379305166,0.5166147388564462,0.10750235318535005,0.3647523055429174,0.6313605622620179,0.03345124403574634,0.023423514943588058,0.02081070235107497,0.39325815414857906,0.1349623039532406,0.05913926510248779,0.5799206039596707,0.231032352734447,0.0473163214537863,0.20452741085605936,0.39521273164381304,0.1349623039532406,0.6941357317821385,0.017039945976584554,0.1111898970505749,0.3250186670563857,0.04639533218041581,0.3607335548238015,0.06393521011957272,0.3132028866226705,0.05097824476462945,0.2907064322118024,0.1813210564603711,0.507616672785669,0.592119595297679,1.2000401659304007,0.33249045268784516,0.34304459627117034,0.09930179180177566,0.3219031430508539,0.0295588022415444,0.4494819935249387,0.009071545824788075,0.3978550166773295,0.25650095496820613,0.0760346862759976,0.18840148402146376,0.3873690238387556,0.681315233326458,0.05638033343610764,0.2583591662970667,0.03826900369069592,0.9117736737104666,0.12326445629462954,0.07980965590369761,0.059946086722379985,0.33380518534256304,0.04573789167385374,0.09893994785490356,0.18417929679260214,0.6128044278774069,0.3307415619122279,0.001998002662673056 ...

# %% [markdown]
# ### **Scatter Plot: Revenue vs. Budget**

# %%
fig = px.scatter(Data, x= 'budget', y= 'revenue',
                 title = 'Revenue vs. Budget',
                 labels = {
                      'budget': 'budget',
                      'revenue' : 'revenue'
                 })
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="f31b99e9-4bb0-461a-bc86-a2bed8552553" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f31b99e9-4bb0-461a-bc86-a2bed8552553")) {                    Plotly.newPlot(                        "f31b99e9-4bb0-461a-bc86-a2bed8552553",                        [{"hovertemplate":"budget=%{x}\u003cbr\u003erevenue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","showlegend":false,"x":[160000000,50000000,150000000,8000000,100000000,100,125000000,30000000,80000000,168000000,18000000,190000000,60000000,175000000,9000000,90000000,72000000,175000000,100000000,340000000,100000000,85000000,70000000,110000000,80000000,28000000,205000000,19000000,165000000,83000000,185000000,116000000,130000000,58000000,6400000,19800000,63000000,144000000,11000000,180000000,1000000,30000000,125000000,152000000,149000000,12000000,220000000,145000000,97000000,250000000,200000000,55000000,200000000,150000000,170000000,55000000,11000000,39000000,175000000,1000000,160000000,165000000,105000000,20000000,47000000,300000000,35000000,274800000,8500000,15000000,100000000,97000000,4500000,60000000,160000000,25000000,110000000,55000000,23000000,18000000,150000000,7000000,50000000,9000000,75000000,8800000,195000000,14000000,27000000,200000000,245000000,250000000,75000000,0,13000000,100000000,33000000,19000000,200000000,200000000,69000000,7000000,78000000,1900000,180000000,90000000,90000000,175000000,30000000,46000000,8000000,93000000,65000000,2800000,110000000,10000000,29000000,34000000,90000000,70000000,165000000,17000000,35000000,129000000,30000000,205000000,25000000,80000000,8000000,100000000,125000000,300000000,175000000,460000000,30000000,125000000,49000000,200000000,6000000,291000000,40000000,60000000,125000000,10000000,95000000,79000000,125000000,100000000,20000000,13000000,170000000,45000000,25000000,17000000,6000000,25000000,80000000,30000000,250000000,100000000,45000000,13000000,200000000,79000000,42000000,24000000,325000,50000000,260000000,68000000,85000000,8500000,22000000,220000000,175000000,14000000,185000000,60000000,7400000,7000000,2000000,4500000,50000000,130000000,70000000,70000000,63000000,200000000,60000000,200000000,35000000,200000000,19000000,40000000,150000000,140000000,60000000,100000000,165000000,90000000,94000000,15000000,17000000,250000000,38500000,11000000,19000000,59000000,94000000,3500000,25000000,10000000,27000000,65000000,13000000,110000000,60000000,20000000,200000000,42000000,75000000,115000000,140000000,100000000,24000000,6000000,25000000,85000000,150000000,40000000,260000000,15000000,90000000,25000000,135000000,110000000,250000000,34000000,200000000,93000000,15000000,140000000,297000000,110000000,200000000,34000000,42000000,200000000,237000000,61000000,178000000,26000000,110000000,9000000,75000000,75000000,6000000,32350000,31000000,175000000,9000000,14000000,90000000,15000000,55000000,75000000,40000000,150000000,25000000,350000,13000000,40000000,104000000,40000000,90000000,20000000,175000000,3300000,150000000,120000000,110000000,25000000,200000000,20000000,70000000,150000000,250000000,69000000,180000000,750000,15000000,130000000,215000000,150000000,25000000,68000000,379000000,19000000,300000000,5800000,13000000,40000000,4500000,294700000,1000000,120000000,65000000,40000000,45000000,37000000,15000000,130000000,19000000,52000000,10000000,250000000,806947,1600000,69000000,250000,55000000,155000000,11000000,365000000,185000000,40000000,139000000,83000000,165000000,35000000,20000000,100000000,40000000,159000000,14000000,150000000,150000000,130000000,90000000,90000000,4000000,160000000,75000000,125000000,175000000,25000000,200000000,250000000,65000000,1500 ...

# %% [markdown]
# ### **Bar plot: Number of Movies vs. Genres**

# %%
Data['genres'] = Data['genres'].apply(lambda x: x.split(', ') if isinstance(x, str) else [])

# Flatten the list of genres and create a DataFrame with the counts
genres_list = Data['genres'].explode()
genre_counts = genres_list.value_counts()

# %%
Data_ = pd.DataFrame(genre_counts)
df =Data_.reset_index()
df.head()
# Out:
#       genres  count
# 0      Drama   1532
# 1     Comedy   1254
# 2     Action   1248
# 3   Thriller   1203
# 4  Adventure    924

# %%
df.shape[0]
# Out:
# 19

# %%
# Plot the bar plot of genre counts with Plotly
fig = px.bar(df, x= 'count', y= 'genres', orientation='h', color= 'genres',
             title='Number of Movies by Genre',
             color_discrete_sequence=px.colors.qualitative.Plotly)

fig.update_layout(xaxis_title='Number of Movies', yaxis_title='Genre', yaxis={'categoryorder':'total ascending'})

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="85c8769f-fa2c-431d-a58a-b87bf279dec6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("85c8769f-fa2c-431d-a58a-b87bf279dec6")) {                    Plotly.newPlot(                        "85c8769f-fa2c-431d-a58a-b87bf279dec6",                        [{"alignmentgroup":"True","hovertemplate":"genres=%{y}\u003cbr\u003ecount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Drama","marker":{"color":"#636EFA","pattern":{"shape":""}},"name":"Drama","offsetgroup":"Drama","orientation":"h","showlegend":true,"textposition":"auto","x":[1532],"xaxis":"x","y":["Drama"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"genres=%{y}\u003cbr\u003ecount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Comedy","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Comedy","offsetgroup":"Comedy","orientation":"h","showlegend":true,"textposition":"auto","x":[1254],"xaxis":"x","y":["Comedy"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"genres=%{y}\u003cbr\u003ecount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Action","marker":{"color":"#00CC96","pattern":{"shape":""}},"name":"Action","offsetgroup":"Action","orientation":"h","showlegend":true,"textposition":"auto","x":[1248],"xaxis":"x","y":["Action"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"genres=%{y}\u003cbr\u003ecount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Thriller","marker":{"color":"#AB63FA","pattern":{"shape":""}},"name":"Thriller","offsetgroup":"Thriller","orientation":"h","showlegend":true,"textposition":"auto","x":[1203],"xaxis":"x","y":["Thriller"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"genres=%{y}\u003cbr\u003ecount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Adventure","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Adventure","offsetgroup":"Adventure","orientation":"h","showlegend":true,"textposition":"auto","x":[924],"xaxis":"x","y":["Adventure"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"genres=%{y}\u003cbr\u003ecount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Crime","marker":{"color":"#19D3F3","pattern":{"shape":""}},"name":"Crime","offsetgroup":"Crime","orientation":"h","showlegend":true,"textposition":"auto","x":[656],"xaxis":"x","y":["Crime"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"genres=%{y}\u003cbr\u003ecount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Science Fiction","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Science Fiction","offsetgroup":"Science Fiction","orientation":"h","showlegend":true,"textposition":"auto","x":[629],"xaxis":"x","y":["Science Fiction"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"genres=%{y}\u003cbr\u003ecount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Horror","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Horror","offsetgroup":"Horror","orientation":"h","showlegend":true,"textposition":"auto","x":[604],"xaxis":"x","y":["Horror"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"genres=%{y}\u003cbr\u003ecount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Romance","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"Romance","offsetgroup":"Romance","orientation":"h","showlegend":true,"textposition":"auto","x":[555],"xaxis":"x","y":["Romance"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"genres=%{y}\u003cbr\u003ecount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Fantasy","marker":{"color":"#FECB52","pattern":{"shape":""}} ...

# %% [markdown]
# ### **Correlation Matrix**

# %%
categorical_data = Data.select_dtypes(include= ['object'])

categorical_cols = [col for col in categorical_data.columns]

numerical_data = Data.select_dtypes(include= ['float64', 'int64'])

numerical_cols =[ num for num in numerical_data.columns]

# %%
corr_matrix = numerical_data.corr()

fig = px.imshow(
    corr_matrix,
    labels = dict(color = 'Correlation'),
    x= corr_matrix.columns,
    y= corr_matrix.columns,
    color_continuous_scale= 'Viridis',
    title = 'Correlation Heatmap'
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="d3481ae9-e6c8-4ab6-952f-636e29c16963" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d3481ae9-e6c8-4ab6-952f-636e29c16963")) {                    Plotly.newPlot(                        "d3481ae9-e6c8-4ab6-952f-636e29c16963",                        [{"coloraxis":"coloraxis","name":"0","x":["id","budget","popularity","runtime","revenue"],"y":["id","budget","popularity","runtime","revenue"],"z":[[1.0,0.05062583954633548,0.18794435024689574,-0.019520354956197097,-0.013402462533781773],[0.05062583954633548,1.0,0.16402657049230843,0.287545266084654,0.6901604427350663],[0.18794435024689574,0.16402657049230843,1.0,0.07836857250329914,0.1532246986080563],[-0.019520354956197097,0.287545266084654,0.07836857250329914,1.0,0.2521185201813994],[-0.013402462533781773,0.6901604427350663,0.1532246986080563,0.2521185201813994,1.0]],"type":"heatmap","xaxis":"x","yaxis":"y","hovertemplate":"x: %{x}\u003cbr\u003ey: %{y}\u003cbr\u003eCorrelation: %{z}\u003cextra\u003e\u003c\u002fextra\u003e"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatter ...
